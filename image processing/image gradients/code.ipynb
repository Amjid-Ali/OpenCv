# %%
import cv2;import numpy as np;import matplotlib.pyplot as plt

# %%
path=r"D:\Amjid_Ali\opencv\OpenCv\image processing\image thresholding\sudoku.jpg"

# %%
img=cv2.imread(path,0)

# %% [markdown]
# #  sobel X, Y

# %%
sobel_X=cv2.Sobel(img,cv2.CV_64F,1,0,ksize=5)
plt.imshow(sobel_X,"gray")

# %%
sobel_y=cv2.Sobel(img,cv2.CV_64F,0,1,ksize=5)
plt.imshow(sobel_y,"gray")

# %% [markdown]
# # laplacian

# %%
laplacian=cv2.Laplacian(img,cv2.CV_64F)
plt.imshow(laplacian,'gray')

# %% [markdown]
# # uint8

# %%
img=cv2.imread("./box.jpg",0)
# 8U
sobelx8u=cv2.Sobel(img,cv2.CV_8U,1,0,ksize=5)
# uint64
sobelx64f=cv2.Sobel(img,cv2.CV_64F,1,0,ksize=5)
#abs
sobel_abs=np.absolute(sobelx64f)
# uint8
sobel_8u=np.uint8(sobelx64f)


plt.subplot(1,3,1),plt.imshow(img,'gray')
plt.title("org"),plt.xticks([]),plt.yticks([])
plt.subplot(1,3,2),plt.imshow(sobelx8u,'gray')
plt.title("8U"),plt.xticks([]),plt.yticks([])
plt.subplot(1,3,3),plt.imshow(sobel_8u,'gray')
plt.title(""),plt.xticks([]),plt.yticks([])
