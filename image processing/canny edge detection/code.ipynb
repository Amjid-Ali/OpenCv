# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
path=r"D:\Amjid_Ali\opencv\OpenCv\core operations on image\basic operations on images\messi.jpg"

# %%
# canny

# %%
img=cv2.imread(path,0)

# %%
canny_edge=cv2.Canny(img,100,200)

# %%
plt.subplot(121),plt.imshow(img,'gray')
plt.title('org image'), plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(canny_edge,'gray')
plt.title('canny_edge'), plt.xticks([]), plt.yticks([])
# Out:
# (Text(0.5, 1.0, 'canny_edge'), ([], []), ([], []))
