# %%
import cv2
import matplotlib.pyplot as plt

# %%
path=r"D:\Amjid_Ali\opencv\OpenCv\Features Detection\sift\sift.jpg"

# %%
image=cv2.imread(path,0)

# %%
image
# Out:
# array([[ 88,  87,  85, ...,  86,  86,  86],
#        [ 88,  87,  85, ...,  83,  84,  84],
#        [ 87,  86,  85, ...,  80,  82,  83],
#        ...,
#        [109, 109, 109, ..., 176, 176, 176],
#        [109, 109, 109, ..., 175, 175, 175],
#        [109, 109, 109, ..., 174, 174, 174]], dtype=uint8)

# %%
orb = cv2.ORB_create(1000)

# %%
kp=orb.detect(image,None)

# %%
kp, des = orb.compute(image, kp)

# %%
img2 = cv2.drawKeypoints(image, kp, None, color=(0,255,0), flags=0)

# %%
plt.imshow(img2)
